# %% [markdown]
# ## Binary Search Tree

# %%
class Node:
    def __init__(self,val=0):
        self.val = val
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def is_empty(self):
        return self.root is None

# %% [markdown]
# #### Leetcode 104. Maximum Depth of Binary Tree
#
# Given the root of a binary tree, return its maximum depth.
#
# A binary tree's maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: 3
# Example 2:
#
# Input: root = [1,null,2]
# Output: 2
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 104].
# -100 <= Node.val <= 100

# %% [markdown]
# #### Using DFS

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root) -> int:
        if root is None:
            return 0
        left_depth = self.maxDepth(root.left)
        right_depth = self.maxDepth(root.right)
        depth = max(left_depth,right_depth) + 1
        return depth

# %% [markdown]
# ### Using BFS

# %%
class Solution:
    def maxDepth(self,root) -> int:
        from collections import deque
        if root is None:
            return 0

        queue = deque([root])
        depth = 0

        while queue:
            level_size = len(queue)

            for _ in range(level_size):
                node = queue.popleft()

                if node.left:
                    queue.append(node.left)

                if node.right:
                    queue.append(node.right)

            depth += 1

        return depth

# %% [markdown]
# #### Leetcode 111. Minimum Depth of Binary Tree
#
# Given a binary tree, find its minimum depth.
#
# The minimum depth is the number of nodes along the shortest path from the root node down to the nearest leaf node.
#
# Note: A leaf is a node with no children.
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: 2
# Example 2:
#
# Input: root = [2,null,3,null,4,null,5,null,6]
# Output: 5
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 105].
# -1000 <= Node.val <= 1000

# %% [markdown]
# ## Using DFS

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def minDepth(self, root) -> int:
        if root is None:
            return 0
        left = self.minDepth(root.left)
        right = self.minDepth(root.right)

        if left == 0:
            min_depth = right + 1
        elif right == 0:
            min_depth = left + 1
        else:
            min_depth = min(left,right) + 1
        return min_depth

# %% [markdown]
# ## Using BFS

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def minDepth(self, root) -> int:
        if root is None:
            return 0
        from collections import deque
        queue = deque([root])
        depth = 0

        while queue:
            level_size = len(queue)

            for _ in range(level_size):
                node = queue.popleft()
                if node.left is None and node.right is None:
                    return depth + 1
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)


            depth += 1

        return depth

# %% [markdown]
# #### Leetcode 100. Same Tree
#
# Given the roots of two binary trees p and q, write a function to check if they are the same or not.
#
# Two binary trees are considered the same if they are structurally identical, and the nodes have the same value.
#
#
#
# Example 1:
#
#
# Input: p = [1,2,3], q = [1,2,3]
# Output: true
# Example 2:
#
#
# Input: p = [1,2], q = [1,null,2]
# Output: false
# Example 3:
#
#
# Input: p = [1,2,1], q = [1,1,2]
# Output: false
#
#
# Constraints:
#
# The number of nodes in both trees is in the range [0, 100].
# -104 <= Node.val <= 104

# %% [markdown]
# ## Using DFS

# %%
class Node:
    def __init__(self,val=0):
        self.val = val
        self.left = None
        self.right = None

class Tree:
    def __init__(self):
        self.root = None

    def isSameTree(self, p,q) -> bool:
        left = True
        right = True
        if p is None and q is None:
            return True
        if p is None and q is not None or p is not None and q is None or p.val != q.val:
            return False
        left = self.isSameTree(p.left,q.left)
        right = self.isSameTree(p.right,q.right)
        return left and right 
        

   

        

t = Node(1)
t.left = Node(2)

t2 = Node(1)
t2.right = Node(2) 

s = Tree()
print(s.isSameTree(t,t2))
# Out:
# False

# %% [markdown]
# ## Using BFS

# %%
class Node:
    def __init__(self,val=0):
        self.val = val
        self.left = None
        self.right = None

class Tree:
    def __init__(self):
        self.root = None

    def isSameTree(self, p,q) -> bool:
        from collections import deque
        queue = deque([(p,q)])

        while queue:
            nodes = queue.popleft()
            if not nodes[0] and not nodes[1]:
                return True
            if nodes[0] and not nodes[1] or nodes[1] and not nodes[0]:
                return False
            if nodes[0].val != nodes[1].val:
                return False
            queue.append((nodes[0].left,nodes[1].left))
            queue.append((nodes[0].right,nodes[1].right))
        return True

        

   

        

t = Node(1)
t.left = Node(2)
t.right = Node(3)

t2 = Node(1)
t2.left = Node(2)
t2.right = Node(3) 

s = Tree()
print(s.isSameTree(t,t2))
# Out:
# False

# %% [markdown]
# #### Leetcode 101. Symmetric Tree
#
# Given the root of a binary tree, check whether it is a mirror of itself (i.e., symmetric around its center).
#
#
#
# Example 1:
#
#
# Input: root = [1,2,2,3,4,4,3]
# Output: true
# Example 2:
#
#
# Input: root = [1,2,2,null,3,null,3]
# Output: false
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [1, 1000].
# -100 <= Node.val <= 100

# %% [markdown]
# ### Using DFS

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def mirror(self,left_root,right_root) -> bool:
        left = True
        right = True
        if left_root is None and right_root is None:
            return True

        if left_root is None and right_root is not None or left_root is not None and right_root is None or left_root.val != right_root.val:
            return False
        left = self.mirror(left_root.left,right_root.right)
        right = self.mirror(left_root.right,right_root.left)
        return left and right


    def isSymmetric(self, root) -> bool:
        return self.mirror(root,root)

t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(2)

t.left.left = TreeNode(3)
t.left.right = TreeNode(4)

t.right.left = TreeNode(4)
t.right.right = TreeNode(3)

r = Solution()
print(r.isSymmetric(t))
# Out:
# True

# %% [markdown]
# ### Using BFS

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def isSymmetric(self, root) -> bool:
        if root is None:
            return True
        
        from collections import deque
        queue = deque([(root.left,root.right)])

        while queue:
            nodes = queue.popleft()
            if nodes[0] is None and nodes[1] is None:
                continue
            if nodes[0] is None and nodes[1] is not None or nodes[0] is not None and nodes[1] is None or nodes[0].val != nodes[1].val:
                return False

            queue.append((nodes[0].left,nodes[1].right))
            queue.append((nodes[0].right,nodes[1].left))

        return True

        

t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(2)

t.left.left = TreeNode(3)
t.left.right = TreeNode(4)

t.right.left = TreeNode(3)
t.right.right = TreeNode(4)

r = Solution()
print(r.isSymmetric(t))
# Out:
# False

# %% [markdown]
# #### Leetcode 226. Invert Binary Tree
#
# Given the root of a binary tree, invert the tree, and return its root.
#
#
#
# Example 1:
#
#
# Input: root = [4,2,7,1,3,6,9]
# Output: [4,7,2,9,6,3,1]
# Example 2:
#
#
# Input: root = [2,1,3]
# Output: [2,3,1]
# Example 3:
#
# Input: root = []
# Output: []
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 100].
# -100 <= Node.val <= 100

# %% [markdown]
# ### Using DFS

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def invertSubTree(self,root,left_tree, right_tree):
        if left_tree is None and right_tree is None:
            return 
        root.left = right_tree
        root.right = left_tree
        if left_tree:
            self.invertSubTree(left_tree,left_tree.left,left_tree.right)
        if right_tree:
            self.invertSubTree(right_tree,right_tree.left,right_tree.right)



    def invertTree(self, root):
        if root is None:
            return None
        self.invertSubTree(root,root.left,root.right)
        return root
        

        

        

t = TreeNode(4)
t.left = TreeNode(2)
t.right = TreeNode(7)

t.left.left = TreeNode(1)
t.left.right = TreeNode(3)

t.right.left = TreeNode(6)
t.right.right = TreeNode(9)

r = Solution()
r = r.invertTree(t)

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    
    def invertTree(self, root):
        if root is None:
            return None
        root.left , root.right = root.right,root.left
        if root.left:
            self.invertTree(root.left)
        if root.right:
            self.invertTree(root.right)
        return root 

        

        

t = TreeNode(4)
t.left = TreeNode(2)
t.right = TreeNode(7)

t.left.left = TreeNode(1)
t.left.right = TreeNode(3)

t.right.left = TreeNode(6)
t.right.right = TreeNode(9)

r = Solution()
r = r.invertTree(t)

# %% [markdown]
# ### Using BFS

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    
    def invertTree(self, root):
        if root is None:
            return None

        from collections import deque
        queue = deque([(root,root.left,root.right)])

        while queue:
            node = queue.popleft()
            if node[1] is None and node[2] is None:
                continue
        
            node[0].left = node[2]
            node[0].right = node[1]
            if node[1]:
                queue.append((node[1],node[1].left,node[1].right))
            if node[2]:
                queue.append((node[2],node[2].left,node[2].right))

        return root 
        

        

t = TreeNode(4)
t.left = TreeNode(2)
t.right = TreeNode(7)

t.left.left = TreeNode(1)
t.left.right = TreeNode(3)

t.right.left = TreeNode(6)
t.right.right = TreeNode(9)

r = Solution()
r = r.invertTree(t)

# %% [markdown]
# #### Leetcode 110. Balanced Binary Tree
#
# Given a binary tree, determine if it is height-balanced.
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: true
# Example 2:
#
#
# Input: root = [1,2,2,3,3,null,null,4,4]
# Output: false
# Example 3:
#
# Input: root = []
# Output: true
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 5000].
# -104 <= Node.val <= 104

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root):
        if root is None:
            return (0,True)
        Balanced = False
        left = self.helper(root.left)
        right = self.helper(root.right)
        if left[1] and right[1]:
            if abs(left[0]-right[0]) <= 1:
                Balanced = True

        max_height = max(left[0],right[0]) + 1
        return (max_height,Balanced)
    
    def isBalanced(self, root) -> bool:
        max_height_and_balanced = self.helper(root)
        return max_height_and_balanced[1]

        
        

        

t = TreeNode(4)
t.left = TreeNode(2)
t.left.left = TreeNode(1)


r = Solution()
print(r.isBalanced(t))
# Out:
# False

# %%
# Without maintaing balance
class Solution:
    def helper(self,root):
        if root is None:
            return 0
        left = self.helper(root.left)
        right = self.helper(root.right)
        if left == -1 or right == -1:
            return -1 

        if abs(left-right) > 1:
            return -1
        

        max_height = max(left,right) + 1
        return max_height
    
    def isBalanced(self, root) -> bool:
        return self.helper(root) != -1

# %% [markdown]
# #### Leetcode 543. Diameter of Binary Tree
#
# Given the root of a binary tree, return the length of the diameter of the tree.
#
# The diameter of a binary tree is the length of the longest path between any two nodes in a tree. This path may or may not pass through the root.
#
# The length of a path between two nodes is represented by the number of edges between them.
#
#
#
# Example 1:
#
#
# Input: root = [1,2,3,4,5]
# Output: 3
# Explanation: 3 is the length of the path [4,2,1,3] or [5,2,1,3].
# Example 2:
#
# Input: root = [1,2]
# Output: 1
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [1, 104].
# -100 <= Node.val <= 100

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root):
        if root is None:
            return (0,0)
        left = self.helper(root.left)
        right = self.helper(root.right)
        max_height = max(left[0],right[0]) + 1
        

        diameter = max(left[1],right[1],left[0]+right[0])
        return (max_height,diameter)

    def diameterOfBinaryTree(self, root) -> int:
        max_height_and_diameter = self.helper(root)
        return max_height_and_diameter[1]
        

        

t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.left = TreeNode(4)
t.right.left = TreeNode(5)





r = Solution()
print(r.diameterOfBinaryTree(t))
# Out:
# 4

# %% [markdown]
# #### Leetcode 112. Path Sum
#
# Given the root of a binary tree and an integer targetSum, return true if the tree has a root-to-leaf path such that adding up all the values along the path equals targetSum.
#
# A leaf is a node with no children.
#
#
#
# Example 1:
#
#
# Input: root = [5,4,8,11,null,13,4,7,2,null,null,null,1], targetSum = 22
# Output: true
# Explanation: The root-to-leaf path with the target sum is shown.
# Example 2:
#
#
# Input: root = [1,2,3], targetSum = 5
# Output: false
# Explanation: There are two root-to-leaf paths in the tree:
# (1 --> 2): The sum is 3.
# (1 --> 3): The sum is 4.
# There is no root-to-leaf path with sum = 5.
# Example 3:
#
# Input: root = [], targetSum = 0
# Output: false
# Explanation: Since the tree is empty, there are no root-to-leaf paths.
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 5000].
# -1000 <= Node.val <= 1000
# -1000 <= targetSum <= 1000

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root,curr_sum,targetSum):
        flag = False
        if root:
            curr_sum += root.val
        if root.left is None and root.right is None and curr_sum == targetSum:
            flag = True
        if flag is False and root.left:
            flag = self.helper(root.left,curr_sum,targetSum)
        if flag is False and root.right:
            flag = self.helper(root.right,curr_sum,targetSum)
        
        return flag

    def hasPathSum(self, root, targetSum: int) -> bool:
        if root is None:
            return False
        return self.helper(root,0,targetSum) 


        

t = TreeNode(1)
t.left = TreeNode(-2)
t.right = TreeNode(-3)
t.left.left = TreeNode(1)
t.left.right = TreeNode(3)
t.right.left = TreeNode(-2)
t.left.left.left = TreeNode(-1)





r = Solution()
print(r.hasPathSum(t,-1))
# Out:
# True

# %%
# use same function 
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def hasPathSum(self, root, targetSum: int) -> bool:
        if root is None:
            return False
        flag = False
        
        targetSum -= root.val
        if root.left is None and root.right is None and targetSum == 0:
            flag = True
        if flag is False and root.left:
            flag = self.hasPathSum(root.left,targetSum)
        if flag is False and root.right:
            flag = self.hasPathSum(root.right,targetSum)
        
        return flag


        

t = TreeNode(1)
t.left = TreeNode(-2)
t.right = TreeNode(-3)
t.left.left = TreeNode(1)
t.left.right = TreeNode(3)
t.right.left = TreeNode(-2)
t.left.left.left = TreeNode(-1)





r = Solution()
print(r.hasPathSum(t,-1))
# Out:
# True

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def hasPathSum(self, root, targetSum: int) -> bool:
        if root is None:
            return False
        from collections import deque
        queue = deque([(root,targetSum-root.val)])

        while queue:
            node = queue.popleft()
            if node[0].left is None and node[0].right is None and node[1] == 0:
                return True
            if node[0].left:
                queue.append((node[0].left,node[1]-node[0].left.val))
            if node[0].right:
                queue.append((node[0].right,node[1]-node[0].right.val))

        return False



        

t = TreeNode(1)
t.left = TreeNode(-2)
t.right = TreeNode(-3)
t.left.left = TreeNode(1)
t.left.right = TreeNode(3)
t.right.left = TreeNode(-2)
t.left.left.left = TreeNode(-1)





r = Solution()
print(r.hasPathSum(t,-1))
# Out:
# True

# %% [markdown]
# #### Leetcode 113. Path Sum II
#
# Given the root of a binary tree and an integer targetSum, return all root-to-leaf paths where the sum of the node values in the path equals targetSum. Each path should be returned as a list of the node values, not node references.
#
# A root-to-leaf path is a path starting from the root and ending at any leaf node. A leaf is a node with no children.
#
#
#
# Example 1:
#
#
# Input: root = [5,4,8,11,null,13,4,7,2,null,null,5,1], targetSum = 22
# Output: [[5,4,11,2],[5,8,4,5]]
# Explanation: There are two paths whose sum equals targetSum:
# 5 + 4 + 11 + 2 = 22
# 5 + 8 + 4 + 5 = 22
# Example 2:
#
#
# Input: root = [1,2,3], targetSum = 5
# Output: []
# Example 3:
#
# Input: root = [1,2], targetSum = 0
# Output: []
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 5000].
# -1000 <= Node.val <= 1000
# -1000 <= targetSum <= 1000

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root,targetSum,answer_list,current_list):
        if root is None:
            return False
        targetSum -= root.val
        current_list.append(root.val)
        if root.left is None and root.right is None and targetSum == 0:
            new_list = current_list.copy()
            answer_list.append(new_list)

        if root.left:
            self.helper(root.left,targetSum,answer_list,current_list)
        if root.right:
            self.helper(root.right,targetSum,answer_list,current_list)
   
        current_list.pop()
      


    def pathSum(self, root, targetSum: int):
        answer_list = []
        current_list = []
        self.helper(root,targetSum,answer_list,current_list)
        return answer_list




        

t = TreeNode(5)
t.left = TreeNode(4)
t.right = TreeNode(8)
t.left.left = TreeNode(11)
t.right.left = TreeNode(13)
t.right.right = TreeNode(4)

t.left.left.left = TreeNode(7)
t.left.left.right = TreeNode(2)

t.right.right.left = TreeNode(5)
t.right.right.right = TreeNode(1)






r = Solution()
print(r.pathSum(t,22))
# Out:
# [[5, 4, 11, 2], [5, 8, 4, 5]]

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    
    def pathSum(self, root, targetSum: int):
        answer = []
        
        if root is None:
            return answer

        from collections import deque
        queue = deque([(root,targetSum-root.val,[root.val])])

        while queue:
            node = queue.popleft()
            if node[0].left is None and node[0].right is None and node[1] == 0:
                answer.append(node[2])
            if node[0].left:
                queue.append((node[0].left,node[1] - node[0].left.val,node[2]+[node[0].left.val]))
            if node[0].right:
                queue.append((node[0].right,node[1] - node[0].right.val,node[2]+[node[0].right.val]))



        return answer





        

t = TreeNode(5)
t.left = TreeNode(4)
t.right = TreeNode(8)
t.left.left = TreeNode(11)
t.right.left = TreeNode(13)
t.right.right = TreeNode(4)

t.left.left.left = TreeNode(7)
t.left.left.right = TreeNode(2)

t.right.right.left = TreeNode(5)
t.right.right.right = TreeNode(1)






r = Solution()
print(r.pathSum(t,22))
# Out:
# [[5, 4, 11, 2], [5, 8, 4, 5]]

# %% [markdown]
# #### Leetcode 257. Binary Tree Paths
#
# Given the root of a binary tree, return all root-to-leaf paths in any order.
#
# A leaf is a node with no children.
#
#
#
# Example 1:
#
#
# Input: root = [1,2,3,null,5]
# Output: ["1->2->5","1->3"]
# Example 2:
#
# Input: root = [1]
# Output: ["1"]
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [1, 100].
# -100 <= Node.val <= 100

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root,answer,current):
        if root is None:
            return 
        if root.left is None and root.right is None:
            answer.append(current)

        if root.left:
            self.helper(root.left,answer,current + "->" + str(root.left.val))
        if root.right:
            self.helper(root.right,answer,current + "->" + str(root.right.val))

    
    def binaryTreePaths(self, root):
        answer = []
        if root:
            current = str(root.val)
            self.helper(root,answer,current)
        return answer
        



t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.right = TreeNode(4)

r = Solution()
print(r.binaryTreePaths(t))
# Out:
# ['1->2->4', '1->3']

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def binaryTreePaths(self, root):
        answer = []
        if root is None:
            return answer

        from collections import deque
        queue = deque([(root,str(root.val))])

        while queue:
            node = queue.popleft()

            if node[0].left is None and node[0].right is None:
                answer.append(node[1])

            if node[0].left:
                queue.append((node[0].left,node[1] + "->" + str(node[0].left.val)))
            if node[0].right:
                queue.append((node[0].right,node[1] + "->" + str(node[0].right.val)))

        return answer
        



t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.right = TreeNode(4)

r = Solution()
print(r.binaryTreePaths(t))
# Out:
# ['1->3', '1->2->4']

# %% [markdown]
# #### Leetcode 222. Count Complete Tree Nodes
#
# Given the root of a complete binary tree, return the number of the nodes in the tree.
#
# According to Wikipedia, every level, except possibly the last, is completely filled in a complete binary tree, and all nodes in the last level are as far left as possible. It can have between 1 and 2h nodes inclusive at the last level h.
#
# Design an algorithm that runs in less than O(n) time complexity.
#
#
#
# Example 1:
#
#
# Input: root = [1,2,3,4,5,6]
# Output: 6
# Example 2:
#
# Input: root = []
# Output: 0
# Example 3:
#
# Input: root = [1]
# Output: 1
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 5 * 104].
# 0 <= Node.val <= 5 * 104
# The tree is guaranteed to be complete.

# %%
# Using O(n) Time complexity - question wants under O(n) time complexity
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def countNodes(self, root) -> int:
        if root is None:
            return 0

        return 1 + self.countNodes(root.left) + self.countNodes(root.right)

    
t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.right = TreeNode(4)

r = Solution()
print(r.countNodes(t))
# Out:
# 4

# %%
# under O(n) time complexity
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def height_left(self,root):
        if root is None:
            return 0
        left = self.height_left(root.left)
        return left+1

    def height_right(self,root):
        if root is None:
            return 0
        right = self.height_right(root.right)
        return right+1

    def countNodes(self, root) -> int:
        if root is None:
            return 0
        left_height = self.height_left(root.left)
        right_height = self.height_right(root.right)
        if left_height == right_height:
            return 2**(left_height+1) -1 
        return 1 + self.countNodes(root.left) + self.countNodes(root.right)


t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.left = TreeNode(4)
t.left.right = TreeNode(5)

r = Solution()
print(r.countNodes(t))
# Out:
# 5

# %% [markdown]
# #### Leetcode 572. Subtree of Another Tree
#
# Given the roots of two binary trees root and subRoot, return true if there is a subtree of root with the same structure and node values of subRoot and false otherwise.
#
# A subtree of a binary tree tree is a tree that consists of a node in tree and all of this node's descendants. The tree tree could also be considered as a subtree of itself.
#
#
#
# Example 1:
#
#
# Input: root = [3,4,5,1,2], subRoot = [4,1,2]
# Output: true
# Example 2:
#
#
# Input: root = [3,4,5,1,2,null,null,null,null,0], subRoot = [4,1,2]
# Output: false
#
#
# Constraints:
#
# The number of nodes in the root tree is in the range [1, 2000].
# The number of nodes in the subRoot tree is in the range [1, 1000].
# -104 <= root.val <= 104
# -104 <= subRoot.val <= 104

# %%
# under O(n) time complexity
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def isSubtree(self, root, subRoot) -> bool:
        flag = False
        if root is None and subRoot is None:
            return True
        
        if root and subRoot and root.val == subRoot.val:
            flag = True
            if root.left and subRoot.left and root.left.val != subRoot.left.val or root.right and subRoot.right and root.right.val != subRoot.right.val:
                flag = False
            else:
                flag = self.isSubtree(root.left,subRoot.left) and self.isSubtree(root.right,subRoot.right)

        if flag is False and root and root.left:
            flag= self.isSubtree(root.left,subRoot)
        if flag is False and root and root.right:
            flag = self.isSubtree(root.right,subRoot)
        return flag




t = TreeNode(3)
t.left = TreeNode(4)
t.right = TreeNode(5)
t.left.left = TreeNode(1)
t.right.left = TreeNode(2)


x = TreeNode(4)
x.left = TreeNode(1)
x.right = TreeNode(2)


r = Solution()
print(r.isSubtree(t,x))
# Out:
# False

# %% [markdown]
# #### Leetcode 572. Subtree of Another Tree
#
# Given the roots of two binary trees root and subRoot, return true if there is a subtree of root with the same structure and node values of subRoot and false otherwise.
#
# A subtree of a binary tree tree is a tree that consists of a node in tree and all of this node's descendants. The tree tree could also be considered as a subtree of itself.
#
#
#
# Example 1:
#
#
# Input: root = [3,4,5,1,2], subRoot = [4,1,2]
# Output: true
# Example 2:
#
#
# Input: root = [3,4,5,1,2,null,null,null,null,0], subRoot = [4,1,2]
# Output: false
#
#
# Constraints:
#
# The number of nodes in the root tree is in the range [1, 2000].
# The number of nodes in the subRoot tree is in the range [1, 1000].
# -104 <= root.val <= 104
# -104 <= subRoot.val <= 104

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def matching(self,root,subRoot):
        flag = True
        if root is not None and subRoot is None or root is None and subRoot is not None or root and subRoot and root.val != subRoot.val:
            flag = False
        if flag:
            if root.left or subRoot.left:
                flag = self.matching(root.left,subRoot.left) and flag
            if root.right or subRoot.right:
                flag = self.matching(root.right,subRoot.right) and flag
       
        return flag
        
    def isSubtree(self, root, subRoot) -> bool:
        flag = False
        left_flag = False
        right_flag = False
        if root is None:
            return 
        if root.val == subRoot.val:
            flag = self.matching(root,subRoot)
        if root.left:
            left_flag = self.isSubtree(root.left,subRoot)
        if root.right:
            right_flag = self.isSubtree(root.right,subRoot)
        return flag or left_flag or right_flag

        



t = TreeNode(1)
t.left = TreeNode(1)




x = TreeNode(1)




r = Solution()
print(r.isSubtree(t,x))
# Out:
# True

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def matching(self,root,subRoot):
        if root is None and subRoot is None:
            return True
        flag = True
        if root is not None and subRoot is None or root is None and subRoot is not None or root and subRoot and root.val != subRoot.val:
            flag = False
        if flag:
            if root.left or subRoot.left:
                flag = self.matching(root.left,subRoot.left) and flag
            if root.right or subRoot.right:
                flag = self.matching(root.right,subRoot.right) and flag
        
        return flag
        
    def isSubtree(self, root, subRoot) -> bool:
        if root is None:
           False
        from collections import deque
        queue = deque([root])
        while queue:
            root = queue.popleft()
            if root.val == subRoot.val:
                if self.matching(root,subRoot):
                    return True
            if root.left:
                queue.append((root.left))
            if root.right:
                queue.append((root.right))
        return False





t = TreeNode(1)
t.left = TreeNode(1)




x = TreeNode(1)

r = Solution()
print(r.isSubtree(t,x))
# Out:
# True

# %% [markdown]
# #### Leetcode 617. Merge Two Binary Trees
# You are given two binary trees root1 and root2.
#
# Imagine that when you put one of them to cover the other, some nodes of the two trees are overlapped while the others are not. You need to merge the two trees into a new binary tree. The merge rule is that if two nodes overlap, then sum node values up as the new value of the merged node. Otherwise, the NOT null node will be used as the node of the new tree.
#
# Return the merged tree.
#
# Note: The merging process must start from the root nodes of both trees.
#
#
#
# Example 1:
#
#
# Input: root1 = [1,3,2,5], root2 = [2,1,3,null,4,null,7]
# Output: [3,4,5,5,4,null,7]
# Example 2:
#
# Input: root1 = [1], root2 = [1,2]
# Output: [2,2]
#
#
# Constraints:
#
# The number of nodes in both trees is in the range [0, 2000].
# -104 <= Node.val <= 104

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def mergeTrees(self, root1, root2):
        if root1 is None:
            return root2
        if root2 is None:
            return root1
        root1.val = root1.val + root2.val
            
        if root1.left is None and root2 and root2.left:
            root1.left = root2.left
        if root1.right is None and root2 and root2.right:
            root1.right = root2.right

        if root1.left != root2.left and root2.left:
            self.mergeTrees(root1.left,root2.left)
        if root1.right != root2.right and root2.right:
            self.mergeTrees(root1.right,root2.right)    

        return root1





t = TreeNode(3)
t.left = TreeNode(4)
t.left.left = TreeNode(1)



x = TreeNode(4)
x.right = TreeNode(2)


r = Solution()
r = r.mergeTrees(t,x)

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def mergeTrees(self, root1, root2):
        if root1 is None:
            return root2
        if root2 is None:
            return root1
        from collections import deque
        merged_root = root1
        queue = deque([(root1,root2)])

        while queue:
            root1,root2 = queue.popleft()
            root1.val += root2.val
            if root1.left is None:
                root1.left = root2.left
            elif root2.left is not None:
                queue.append((root1.left, root2.left))

            if root1.right is None:
                root1.right = root2.right
            elif root2.right is not None:
                queue.append((root1.right,root2.right))

        return merged_root



t = TreeNode(3)
t.left = TreeNode(4)
t.left.left = TreeNode(1)



x = TreeNode(4)
x.right = TreeNode(2)


r = Solution()
r = r.mergeTrees(t,x)

# %% [markdown]
# #### Leetcode 404. Sum of Left Leaves
#
# Given the root of a binary tree, return the sum of all left leaves.
#
# A leaf is a node with no children. A left leaf is a leaf that is the left child of another node.
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: 24
# Explanation: There are two left leaves in the binary tree, with values 9 and 15 respectively.
# Example 2:
#
# Input: root = [1]
# Output: 0
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [1, 1000].
# -1000 <= Node.val <= 1000

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def sumOfLeftLeaves(self, root):
        if root is None:
            return 0
        total = 0
        if root.left and not root.left.left and not root.left.right:
            total += root.left.val
        if root.left:
            total += self.sumOfLeftLeaves(root.left)
        if root.right:
            total += self.sumOfLeftLeaves(root.right)
        return total

        




t = TreeNode(3)
t.left = TreeNode(9)
t.right = TreeNode(20)
t.right.left = TreeNode(15)
t.right.right = TreeNode(7)



r = Solution()
print(r.sumOfLeftLeaves(t))
# Out:
# 24

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def sumOfLeftLeaves(self, root):
        total = 0
        if root is None:
            return total
        
        from collections import deque
        queue = deque([root])

        while queue:
            node = queue.popleft()
            if node.left and not node.left.left and not node.left.right:
                total += node.left.val

            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
        
        return total

        




t = TreeNode(3)
t.left = TreeNode(9)
t.right = TreeNode(20)
t.right.left = TreeNode(15)
t.right.right = TreeNode(7)



r = Solution()
print(r.sumOfLeftLeaves(t))
# Out:
# 24

# %% [markdown]
# #### Leetcode 102. Binary Tree Level Order Traversal
#
# Given the root of a binary tree, return the level order traversal of its nodes' values. (i.e., from left to right, level by level).
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: [[3],[9,20],[15,7]]
# Example 2:
#
# Input: root = [1]
# Output: [[1]]
# Example 3:
#
# Input: root = []
# Output: []

# %% [markdown]
# ### Using DFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root,answer,height):
        if len(answer) < height:
            answer.append([])
        answer[height-1].append(root.val)
        if root.left:
            self.helper(root.left,answer,height +1)
        if root.right:
            self.helper(root.right,answer,height+1)


    def levelOrder(self, root):
        answer = []
        height = 1
        if root is None:
            return answer
        self.helper(root,answer,height)
        return answer
        
        

t = TreeNode(3)
t.left = TreeNode(9)
t.right = TreeNode(20)
t.right.left = TreeNode(15)
t.right.right = TreeNode(7)



r = Solution()
print(r.levelOrder(t))
# Out:
# [[3], [9, 20], [15, 7]]

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def levelOrder(self, root):
        answer = []
        if root is None:
            return answer
        
        from collections import deque
        queue = deque([root])
        
        while queue:
            level_size = len(queue)
            curr = []
            
            for _ in range(level_size):
                node = queue.popleft()
                curr.append(node.val)
                
                
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            answer.append(curr)
            
        return answer

t = TreeNode(3)
t.left = TreeNode(9)
t.right = TreeNode(20)
t.right.left = TreeNode(15)
t.right.right = TreeNode(7)



r = Solution()
print(r.levelOrder(t))
# Out:
# [[3], [9, 20], [15, 7]]

# %% [markdown]
# #### Leetcode 199. Binary Tree Right Side View
#
# Given the root of a binary tree, imagine yourself standing on the right side of it, return the values of the nodes you can see ordered from top to bottom.
#
#
#
# Example 1:
#
# Input: root = [1,2,3,null,5,null,4]
#
# Output: [1,3,4]
#
# Explanation:
#
#
#
# Example 2:
#
# Input: root = [1,2,3,4,null,null,null,5]
#
# Output: [1,3,4,5]
#
# Explanation:
#
#
#
# Example 3:
#
# Input: root = [1,null,3]
#
# Output: [1,3]
#
# Example 4:
#
# Input: root = []
#
# Output: []
#
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 100].
# -100 <= Node.val <= 100

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def rightSideView(self, root):
        answer = []
        if root is None:
            return answer
        
        from collections import deque
        queue = deque([root])
        
        while queue:
            level_size = len(queue)
            curr = []
            
            for _ in range(level_size):
                node = queue.popleft()
                curr.append(node.val)
                
                
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            answer.append(curr[-1])
            
        return answer

t = TreeNode(3)
t.left = TreeNode(9)
t.right = TreeNode(20)
t.right.left = TreeNode(15)
t.right.right = TreeNode(7)



r = Solution()
print(r.rightSideView(t))
# Out:
# [3, 20, 7]

# %% [markdown]
# #### Custom question : Left view

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def leftSideView(self, root):
        answer = []
        if root is None:
            return answer
        
        from collections import deque
        queue = deque([root])
        
        while queue:
            level_size = len(queue)
            curr = []
            
            for _ in range(level_size):
                node = queue.popleft()
                curr.append(node.val)
                
                
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            answer.append(curr[0])
            
        return answer
        
t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.right.left = TreeNode(4)
t.right.right = TreeNode(5)
t.right.right.left = TreeNode(6)



r = Solution()
print(r.leftSideView(t))
# Out:
# [1, 2, 4, 6]

# %% [markdown]
# #### Top view

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def TopView(self, root):
        from collections import deque
        answer = []
        if root is None:
            return answer
        horizontal_distance = 0
        queue = deque([(root,horizontal_distance)])
        hashmap = {}
        while queue:
            node,horizontal_distance = queue.popleft()
            if horizontal_distance not in hashmap:
                hashmap[horizontal_distance] = node.val

            if node.left:
                queue.append((node.left,horizontal_distance-1))
            if node.right:
                queue.append((node.right,horizontal_distance+1))

        for i in range(min(hashmap),max(hashmap)+1):
            answer.append(hashmap[i])
        return answer


        
t = TreeNode(4)
t.right = TreeNode(8)
t.right.right = TreeNode(5)
t.right.right.left = TreeNode(9)
t.right.right.right = TreeNode(9)



r = Solution()
print(r.TopView(t))
# Out:
# [4, 8, 5, 9]

# %% [markdown]
# #### Bottom View

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def BottomView(self, root):
        from collections import deque
        answer = []
        if root is None:
            return answer
        horizontal_distance = 0
        queue = deque([(root,horizontal_distance)])
        hashmap = {}
        while queue:
            node,horizontal_distance = queue.popleft()
            hashmap[horizontal_distance] = node.val

            if node.left:
                queue.append((node.left,horizontal_distance-1))
            if node.right:
                queue.append((node.right,horizontal_distance+1))

        for i in range(min(hashmap),max(hashmap)+1):
            answer.append(hashmap[i])
        return answer


        
t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.left = TreeNode(4)
t.left.right = TreeNode(5)


t.right.right = TreeNode(6)
t.left.right.left = TreeNode(7)
t.left.right.right = TreeNode(8)





r = Solution()
print(r.BottomView(t))
# Out:
# [4, 7, 5, 8, 6]

# %% [markdown]
# #### Vertical order

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def VerticalView(self, root):
        from collections import deque
        answer = []
        if root is None:
            return answer
        horizontal_distance = 0
        queue = deque([(root,horizontal_distance)])
        hashmap = {}
        while queue:
            node,horizontal_distance = queue.popleft()
            if horizontal_distance in hashmap:
                hashmap[horizontal_distance].append(node.val)
            else:
                hashmap[horizontal_distance] = [node.val]

            if node.left:
                queue.append((node.left,horizontal_distance-1))
            if node.right:
                queue.append((node.right,horizontal_distance+1))

        for i in range(min(hashmap),max(hashmap)+1):
            answer.append(hashmap[i])
        return answer


        
t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.left = TreeNode(4)
t.left.right = TreeNode(5)


t.right.right = TreeNode(6)
t.left.right.right = TreeNode(7)





r = Solution()
print(r.VerticalView(t))
# Out:
# [[4], [2], [1, 5], [3, 7], [6]]

# %% [markdown]
# #### Boundary traversal (leetcode 545)

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def left_boundary(self,root,answer):
        if root is None:
            return answer 

        if root.left is None and root.right is None:
            return answer

        answer.append(root.val)

        if root.left:
            self.left_boundary(root.left,answer)
        else:
            self.left_boundary(root.right,answer)
        return answer 
    def right_boundary(self,root,answer):
        if root is None:
            return answer

        if root.left is None and root.right is None:
            return answer

        answer.append(root.val)

        if root.right:
            self.right_boundary(root.right,answer)
        else:
            self.right_boundary(root.left,answer)
        return answer 
    
    def leaves(self,root,answer):
        if root is None:
            return answer
        if root.left is None and root.right is None:
            answer.append(root.val)
            return answer
        
        if root.left:
            answer = self.leaves(root.left,answer)
        if root.right:
            answer = self.leaves(root.right,answer)
        return answer 


    def BoundaryTraversal(self, root):
        if root is None:
            return []
        root_value = [root.val]
        left_list = []
        right_list = []
        leaves = []
        if root.left:
            left_list = self.left_boundary(root.left,left_list)
            right_list = self.right_boundary(root.right,right_list)
            right_list.reverse()
        else:
            left_list = self.left_boundary(root.right,left_list)
        leaves = self.leaves(root,leaves)
        boundary = root_value + left_list + leaves+ right_list
        return boundary
        

        


        
t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)
t.left.left = TreeNode(4)
t.left.right = TreeNode(5)


t.right.right = TreeNode(6)
t.left.right.left = TreeNode(7)

t.left.right.right = TreeNode(8)





r = Solution()
print(r.BoundaryTraversal(t))
# Out:
# [1, 2, 4, 7, 8, 6, 3]

# %% [markdown]
# #### Diagonal Traversal

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root,answer,queue):
        if root is None:
            if len(queue) == 0:
                return answer
            while queue:
                node = queue.popleft()
                self.helper(node,answer,queue)
        if root:
            answer.append(root.val)
        if root and root.left:
            queue.append(root.left)
        if root:
            self.helper(root.right,answer,queue)
        return answer
            


    def diagonalTraversal(self,root):
        answer = []
        if root is None:
            return answer
        from collections import deque
        queue = deque()

        self.helper(root,answer,queue)
        return answer
        
    
        

        


        
t = TreeNode(10)
t.left = TreeNode(5)
t.right = TreeNode(20)

t.left.right = TreeNode(8)
t.left.right.right = TreeNode(9)
t.left.right.right.left = TreeNode(7)

t.right.right = TreeNode(30)
t.right.right.left = TreeNode(25)



t.left.left = TreeNode(2)
t.left.left.right = TreeNode(4)

root = TreeNode(1)
node2 = TreeNode(2)
node3 = TreeNode(3)
node4 = TreeNode(4)
node5 = TreeNode(5)
node6 = TreeNode(6)
node7 = TreeNode(7)
node8 = TreeNode(8)

# 2. Connect the nodes according to the structure
root.left = node2
root.right = node3

node2.left = node4

node3.left = node5
node3.right = node6

node4.right = node7

node6.right = node8

r = Solution()
print(r.diagonalTraversal(root))
# Out:
# [1, 3, 6, 8, 2, 5, 4, 7]

# %% [markdown]
# ### Leetcode 637. Average of Levels in Binary Tree
# Given the root of a binary tree, return the average value of the nodes on each level in the form of an array. Answers within 10-5 of the actual answer will be accepted.
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: [3.00000,14.50000,11.00000]
# Explanation: The average value of nodes on level 0 is 3, on level 1 is 14.5, and on level 2 is 11.
# Hence return [3, 14.5, 11].
# Example 2:
#
#
# Input: root = [3,9,20,15,7]
# Output: [3.00000,14.50000,11.00000]

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def averageOfLevels(self, root):
        answer = []
        if root is None:
            return answer
        
        from collections import deque
        queue = deque([root])
        
        while queue:
            level_size = len(queue)
            level_total = 0
            
            for _ in range(level_size):
                node = queue.popleft()
                level_total += node.val
                
                
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            answer.append(level_total/level_size)
            
        return answer

t = TreeNode(3)
t.left = TreeNode(9)
t.right = TreeNode(20)
t.right.left = TreeNode(15)
t.right.right = TreeNode(7)



r = Solution()
print(r.averageOfLevels(t))
# Out:
# [3.0, 14.5, 11.0]

# %% [markdown]
# #### Leecode 103. Binary Tree Zigzag Level Order Traversal
#
# Given the root of a binary tree, return the zigzag level order traversal of its nodes' values. (i.e., from left to right, then right to left for the next level and alternate between).
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: [[3],[20,9],[15,7]]
# Example 2:
#
# Input: root = [1]
# Output: [[1]]
# Example 3:
#
# Input: root = []
# Output: []
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 2000].
# -100 <= Node.val <= 100

# %% [markdown]
# ### Using BFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def zigzagLevelOrder(self,root):
        answer = []

        if root is None:
            return answer

        from collections import deque
        queue = deque([root])
        height = 0
        while queue:
            level_size = len(queue)
            height += 1

            curr = []
            for _ in range(level_size):
                node = queue.popleft()
                curr.append(node.val)

                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            if height % 2 ==0:
                curr.reverse()
            answer.append(curr)
        return answer

t = TreeNode(3)
t.left = TreeNode(9)
t.right = TreeNode(20)
t.right.left = TreeNode(15)
t.right.right = TreeNode(7)



r = Solution()
print(r.zigzagLevelOrder(t))
# Out:
# [[3], [20, 9], [15, 7]]

# %% [markdown]
# ### Leetcode 236. Lowest Common Ancestor of a Binary Tree
# Medium
# Topics
# premium lock icon
# Companies
# Given a binary tree, find the lowest common ancestor (LCA) of two given nodes in the tree.
#
# According to the definition of LCA on Wikipedia: “The lowest common ancestor is defined between two nodes p and q as the lowest node in T that has both p and q as descendants (where we allow a node to be a descendant of itself).”
#
#
#
# Example 1:
#
#
# Input: root = [3,5,1,6,2,0,8,null,null,7,4], p = 5, q = 1
# Output: 3
# Explanation: The LCA of nodes 5 and 1 is 3.
# Example 2:
#
#
# Input: root = [3,5,1,6,2,0,8,null,null,7,4], p = 5, q = 4
# Output: 5
# Explanation: The LCA of nodes 5 and 4 is 5, since a node can be a descendant of itself according to the LCA definition.
# Example 3:
#
# Input: root = [1,2], p = 1, q = 2
# Output: 1

# %% [markdown]
# ### Using DFS

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def lowestCommonAncestor(self, root, p, q):
        if root is None:
            return None
        if root == p or root == q:
            return root
        

        left_result = self.lowestCommonAncestor(root.left,p,q)
        right_result = self.lowestCommonAncestor(root.right,p,q)

        if left_result and right_result:
            return root
        if left_result:
            return left_result
        if right_result:
            return right_result
    
t = TreeNode(3)
t.left = TreeNode(5)
t.right = TreeNode(1)
t.left.left = TreeNode(6)
t.left.right = TreeNode(2)


t.right.left = TreeNode(0)
t.right.right = TreeNode(8)
t.left.right.left = TreeNode(7)
t.left.right.right = TreeNode(4)

p = t.left
q = t.left.right.right


r = Solution()
node = r.lowestCommonAncestor(t, p, q)
print(node.val)
# Out:
# 5

# %% [markdown]
# #### Leetcode 105. Construct Binary Tree from Preorder and Inorder Traversal
#
# Given two integer arrays preorder and inorder where preorder is the preorder traversal of a binary tree and inorder is the inorder traversal of the same tree, construct and return the binary tree.
#
#
#
# Example 1:
#
#
# Input: preorder = [3,9,20,15,7], inorder = [9,3,15,20,7]
# Output: [3,9,20,null,null,15,7]
# Example 2:
#
# Input: preorder = [-1], inorder = [-1]
# Output: [-1]
#
#
# Constraints:
#
# 1 <= preorder.length <= 3000
# inorder.length == preorder.length
# -3000 <= preorder[i], inorder[i] <= 3000
# preorder and inorder consist of unique values.
# Each value of inorder also appears in preorder.
# preorder is guaranteed to be the preorder traversal of the tree.
# inorder is guaranteed to be the inorder traversal of the tree.

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def buildTree(self, preorder,inorder):
        root = None
        if len(preorder) == 0:
            return root
        root = TreeNode(preorder[0])
        root_index = inorder.index(preorder[0])
        root.left = self.buildTree(preorder[1:root_index+1],inorder[:root_index])
        root.right = self.buildTree(preorder[root_index+1:],inorder[root_index+1:])
            
        return root 
        

        
        
    
preorder = [3,9,20,15,7]
inorder = [9,3,15,20,7]


r = Solution()
r.buildTree(preorder,inorder)

# %%
## Optimized version , time complexity - O(n)
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def buildTree(self, preorder, inorder):

        # Store inorder value -> index
        inorder_map = {
            value: index
            for index, value in enumerate(inorder)
        }

        def build(pre_left, pre_right, in_left, in_right):

            # No nodes in this subtree
            if pre_left > pre_right:
                return None

            # Preorder gives us the root
            root_val = preorder[pre_left]
            root = TreeNode(root_val)

            # Find root position in inorder in O(1)
            root_index = inorder_map[root_val]

            # Number of nodes in left subtree
            left_size = root_index - in_left

            # Build left subtree
            root.left = build(
                pre_left + 1,
                pre_left + left_size,
                in_left,
                root_index - 1
            )

            # Build right subtree
            root.right = build(
                pre_left + left_size + 1,
                pre_right,
                root_index + 1,
                in_right
            )

            return root

        return build(
            0,
            len(preorder) - 1,
            0,
            len(inorder) - 1
        )

preorder = [3,9,20,15,7]
inorder = [9,3,15,20,7]


r = Solution()
r.buildTree(preorder,inorder)

# %% [markdown]
# #### Leetcode 106. Construct Binary Tree from Inorder and Postorder Traversal
#
# Given two integer arrays inorder and postorder where inorder is the inorder traversal of a binary tree and postorder is the postorder traversal of the same tree, construct and return the binary tree.
#
#
#
# Example 1:
#
#
# Input: inorder = [9,3,15,20,7], postorder = [9,15,7,20,3]
# Output: [3,9,20,null,null,15,7]
# Example 2:
#
# Input: inorder = [-1], postorder = [-1]
# Output: [-1]
#
#
# Constraints:
#
# 1 <= inorder.length <= 3000
# postorder.length == inorder.length
# -3000 <= inorder[i], postorder[i] <= 3000
# inorder and postorder consist of unique values.
# Each value of postorder also appears in inorder.
# inorder is guaranteed to be the inorder traversal of the tree.
# postorder is guaranteed to be the postorder traversal of the tree.

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:

    def buildTree(self,inorder,postorder):
        if len(postorder) == 0:
            return None
        root = TreeNode(postorder[-1])
        root_index = inorder.index(postorder[-1])
        root.left = self.buildTree(inorder[:root_index],postorder[:root_index])
        root.right = self.buildTree(inorder[root_index+1:],postorder[root_index:-1])

        return root

        

        
        
    

inorder = [9,3,15,20,7]
postorder = [9,15,7,20,3]


r = Solution()
r.buildTree(inorder,postorder)

# %%
## Optimized version , time complexity - O(n)
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def buildTree(self,inorder,postorder):

        # Store inorder value -> index
        inorder_map = {
            value: index
            for index, value in enumerate(inorder)
        }

        def build(post_left, post_right, in_left, in_right):

            # No nodes in this subtree
            if post_left > post_right:
                return None

            # Preorder gives us the root
            root_val = postorder[post_right]
            root = TreeNode(root_val)

            # Find root position in inorder in O(1)
            root_index = inorder_map[root_val]

            # Number of nodes in left subtree
            left_size = root_index - in_left

            # Build left subtree
            root.left = build(
                post_left  ,
                left_size + post_left - 1,
                in_left,
                root_index - 1
            )

            # Build right subtree
            root.right = build(
                post_left + left_size ,
                post_right - 1,
                root_index + 1,
                in_right
            )

            return root

        return build(
            0,
            len(postorder) - 1,
            0,
            len(inorder) - 1
        )

inorder = [9,3,15,20,7]
postorder = [9,15,7,20,3]



r = Solution()
r.buildTree(inorder,postorder)

# %% [markdown]
# #### Leetcode 297. Serialize and Deserialize Binary Tree
# Hard
# Topics
# premium lock icon
# Companies
# Serialization is the process of converting a data structure or object into a sequence of bits so that it can be stored in a file or memory buffer, or transmitted across a network connection link to be reconstructed later in the same or another computer environment.
#
# Design an algorithm to serialize and deserialize a binary tree. There is no restriction on how your serialization/deserialization algorithm should work. You just need to ensure that a binary tree can be serialized to a string and this string can be deserialized to the original tree structure.
#
# Clarification: The input/output format is the same as how LeetCode serializes a binary tree. You do not necessarily need to follow this format, so please be creative and come up with different approaches yourself.
#
#
#
# Example 1:
#
#
# Input: root = [1,2,3,null,null,4,5]
# Output: [1,2,3,null,null,4,5]
# Example 2:
#
# Input: root = []
# Output: []
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [0, 104].
# -1000 <= Node.val <= 1000

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    

    def serialize(self, root):
        """Encodes a tree to a single string.
        
        :type root: TreeNode
        :rtype: str
        """
        if root is None:
            return ""
        from collections import deque
        queue = deque([root])
        data = []
        while queue:
            
            node = queue.popleft()
            if node:
                data.append(node.val)
            else:
                data.append(None)
            if node:
                queue.append(node.left)
                queue.append(node.right)

        while data[-1] == None:
            data.pop()
        answer_string = ",".join(str(x) for x in data)

        return answer_string




    def deserialize(self, data):
        """Decodes your encoded data to tree.
        
        :type data: str
        :rtype: TreeNode
        """
        if not data:
            return None

        data = data.split(",")

        root = TreeNode(int(data[0]))
        from collections import deque
        queue = deque([root])

        index = 1

        while queue and index < len(data):

            node = queue.popleft()

            # Left child
            if data[index] != "None":
                node.left = TreeNode(int(data[index]))
                queue.append(node.left)

            index += 1

            if index >= len(data):
                break

            # Right child
            if data[index] != "None":
                node.right = TreeNode(int(data[index]))
                queue.append(node.right)

            index += 1

        return root
    

data = "1,2,3,None,None,4,5,6,7"


t = TreeNode(1)
t.left = TreeNode(2)
t.right = TreeNode(3)



t.right.left = TreeNode(4)
t.right.left.left = TreeNode(6)
t.right.left.right = TreeNode(7)
t.right.right = TreeNode(5)

r = Solution()

new = r.serialize(t)
r.deserialize(new)
