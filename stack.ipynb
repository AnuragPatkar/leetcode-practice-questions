# %%
class stack:
    def __init__(self):
        self._items = []

    def push(self,num):
        self._items.append(num)

    def peek(self):
        if not self.is_empty():
            return self._items[-1]
        raise IndexError("The stack is empty")


    def pop(self):
        if not self.is_empty():
            return self._items.pop()
        raise IndexError("The stack is empty")

    def is_empty(self):
        return len(self._items) == 0

    def size(self):
        return len(self._items)


s = stack()

print(s.is_empty())
s.push(10)
s.push(20)
s.push(30)
print(s.peek())
print(s.pop())
print(s.peek())
# Out:
# True
# 30
# 30
# 20

# %% [markdown]
# #### Leetcode 20. Valid Parentheses
#
# Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
# Every close bracket has a corresponding open bracket of the same type.
#
#
# Example 1:
#
# Input: s = "()"
#
# Output: true
#
# Example 2:
#
# Input: s = "()[]{}"
#
# Output: true
#
# Example 3:
#
# Input: s = "(]"
#
# Output: false
#
# Example 4:
#
# Input: s = "([])"
#
# Output: true
#
# Example 5:
#
# Input: s = "([)]"
#
# Output: false
#
#
#
# Constraints:
#
# 1 <= s.length <= 104
# s consists of parentheses only '()[]{}'.

# %%
def isValid(s):
    stack = []
    hashmap = {
                ')':'(',
                '}':'{',
                ']':'['
                }
    for ch in s:
        if ch not in hashmap:
            stack.append(ch)
        else:
            if not stack:
                return False
            if stack[-1] == hashmap[ch]:
                stack.pop()
            else:
                return False
    
    if not stack:
        return True
    else:
        return False
# Out:
# {')': '(', '}': '{', ']': '['}

# %% [markdown]
# #### Leetcode 155. Min Stack
#
# Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.
#
# Implement the MinStack class:
#
# MinStack() initializes the stack object.
# void push(int value) pushes the element value onto the stack.
# void pop() removes the element on the top of the stack.
# int top() gets the top element of the stack.
# int getMin() retrieves the minimum element in the stack.
# You must implement a solution with O(1) time complexity for each function.
#
#
#
# Example 1:
#
# Input
# ["MinStack","push","push","push","getMin","pop","top","getMin"]
# [[],[-2],[0],[-3],[],[],[],[]]
#
# Output
# [null,null,null,null,-3,null,0,-2]
#
# Explanation
# MinStack minStack = new MinStack();
# minStack.push(-2);
# minStack.push(0);
# minStack.push(-3);
# minStack.getMin(); // return -3
# minStack.pop();
# minStack.top();    // return 0
# minStack.getMin(); // return -2
#
#
# Constraints:
#
# -231 <= val <= 231 - 1
# Methods pop, top and getMin operations will always be called on non-empty stacks.
# At most 3 * 104 calls will be made to push, pop, top, and getMin

# %%
class MinStack:

    def __init__(self):
        self.item_minimum = []

    def push(self, value):
        if not self.item_minimum:
            current_min = value
        else:
            current_min = min(value, self.item_minimum[-1][1])

        self.item_minimum.append((value,current_min))
        
        

    def pop(self) -> None:
        if self.item_minimum:
            self.item_minimum.pop()
        # raise IndexError("The Min Stack is Empty.")
        

    def top(self) -> int:
        if self.item_minimum:
            return self.item_minimum[-1][0]
        
        # raise IndexError("The Min Stack is Empty.")

    def getMin(self) -> int:
        if self.item_minimum:
            return self.item_minimum[-1][1]
        # raise IndexError("The Min Stack is Empty.")
        


# Your MinStack object will be instantiated and called as such:
minStack = MinStack()
minStack.push(2)
minStack.push(2)
minStack.push(3)
print(minStack.getMin())
print(minStack.pop())
print(minStack.top())
print(minStack.getMin())
# Out:
# 2
# None
# 2
# 2
